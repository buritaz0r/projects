# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Андрей, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
# Я не смогу принять проект, если в нём будет хотя бы одна критичная ошибка или несколько некритичных ошибок - тогда проект нужно будет немного доработать. Но это нестрашно - я обязательно дам тебе подсказку или укажу верное направление.
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Комментарий ревьюера </b>
#
# Андрей, проект списан из https://github.com/deleusis/Data-Science-Gold-Recovery/blob/main/gold_recovery.ipynb. Нужно передать с нуля, самостоятельно.
#
# Дополнительные задания для модельного блока:
# - дополнительно исследовать `Lasso`, `RandomForestRegressor`: для `Lasso` оптимизировать один гиперпараметр, для случайного леса и дерева регений - не менее двух;
# - оптимизацию гиперпараметров выполнить через `GridSerachCV`;
# - выполнить шкалирование переменных через `StandardScaler`.
#
# Дополнительные задания для аналитического блока:
# - для визуализации использовать `sns.histplot()`, настроить правильное количество корзин и разные цвета для разных признаков;
# - при анализе схожести распределений использовать `sns.histplot()` с настройкой на нормированные гистограммы, дополнительно провести `ttest` на равенство средних: сформулировать гипотезы, провести тесты, сделать выводы по проверке.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Алексей, привет! Да, проект частично списал, спешу из-за дедлайна в воскресенье(, постарался все сделать заново, также были выполнены твои дополнительные задания.
#
# А именно:
#
# 1. Для визуализации концентрации металлов на различных этапах обработки использовать я использовал sns.histplot().
#
# 2. При анализе схожести распределений также использовал sns.histplot() с настройкой на нормированные гистограммы, дополнительно провел t-test на равенство средних, на основе которого подтвердилось, что средние значения размеров гранул схожи.
#
# 3. Исследовал модели Lasso, RandomForestRegressor и DecisionTreeRegressor. Для Lasso оптимизировал один гиперпараметр, для случайного леса и дерева решений - 2 и 3.
# ```
# lasso_params = {'lasso__alpha': [0.001, 0.01, 0.1, 1.0]}
# rf_params = {
#     'randomforestregressor__n_estimators': [10,50],
#     'randomforestregressor__max_depth': [None, 5, 10]
# }
# dtr_params = {
#     'decisiontreeregressor__max_depth': [None, 10, 20],
#     'decisiontreeregressor__min_samples_split': [2, 5, 10],
#     'decisiontreeregressor__min_samples_leaf': [1, 2, 4]
# }
# ```
# 4. Оптимизацию гиперпараметров выполнил с помощью GridSerachCV.
#
# 5. Также выполнено шкалирование переменных через StandardScaler.
#
# 6. Каждая модель обучалась ооочень долго, поэтому параметры пришлось взять именно такие, в обучении моделей везде добавил прогресс-бар с помощью библиотеки **from tqdm import tqdm**.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Давай смотреть:)

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Откройте-файлы-и-изучите-их" data-toc-modified-id="Откройте-файлы-и-изучите-их-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Откройте файлы и изучите их</a></span></li><li><span><a href="#Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы." data-toc-modified-id="Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.</a></span></li><li><span><a href="#Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?" data-toc-modified-id="Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?</a></span></li><li><span><a href="#Проведите-предобработку-данных." data-toc-modified-id="Проведите-предобработку-данных.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проведите предобработку данных.</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах:-в-сырье,-в-черновом-концентрате,-в-концентрате-после-первой-очистки-и-в-финальном-концентрате.-Какие-особенности-имеют-распределения?-Опишите-выводы." data-toc-modified-id="Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах:-в-сырье,-в-черновом-концентрате,-в-концентрате-после-первой-очистки-и-в-финальном-концентрате.-Какие-особенности-имеют-распределения?-Опишите-выводы.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате. Какие особенности имеют распределения? Опишите выводы.</a></span></li><li><span><a href="#Сравните-распределения-размеров-гранул-исходного-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной." data-toc-modified-id="Сравните-распределения-размеров-гранул-исходного-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравните распределения размеров гранул исходного сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.</a></span></li><li><span><a href="#Исследуйте-суммарную-концентрацию-металлов-на-разных-стадиях:-в-сырье,-в-черновом-концентрате,-в-концентрате-после-первой-очистки-и-в-финальном-концентрате." data-toc-modified-id="Исследуйте-суммарную-концентрацию-металлов-на-разных-стадиях:-в-сырье,-в-черновом-концентрате,-в-концентрате-после-первой-очистки-и-в-финальном-концентрате.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследуйте суммарную концентрацию металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Напишите-функцию-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Напишите-функцию-для-вычисления-итоговой-sMAPE.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Напишите функцию для вычисления итоговой sMAPE.</a></span></li><li><span><a href="#Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы." data-toc-modified-id="Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.</a></span></li><li><span><a href="#Проверим-модель-на-тестовой-выборке" data-toc-modified-id="Проверим-модель-на-тестовой-выборке-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Проверим модель на тестовой выборке</a></span></li><li><span><a href="#Проверим-модель-на-адекватность." data-toc-modified-id="Проверим-модель-на-адекватность.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Проверим модель на адекватность.</a></span></li></ul></li><li><span><a href="#Общий-вывод." data-toc-modified-id="Общий-вывод.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Общий вывод.</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Откройте файлы и изучите их

# %%
# Импортируем библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

from tqdm import tqdm

from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_error, fbeta_score, make_scorer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, cross_val_predict, GridSearchCV
from sklearn.dummy import DummyRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import make_scorer

import warnings

warnings.filterwarnings("ignore")

# %%
# Загрузка обучающей выборки
train_data = pd.read_csv('/datasets/gold_industry_train.csv')

# Загрузка тестовой выборки
test_data = pd.read_csv('/datasets/gold_industry_test.csv')

# Загрузка исходных данных
full_data = pd.read_csv('/datasets/gold_industry_full.csv')

# %%
# Изучим данные

data_all = [train_data, test_data, full_data]
for dataset in data_all:
    display(dataset.info())
    print('-----')
    display(dataset.describe())
    print('-----')
    print('Количество дубликатов:', dataset.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14579 entries, 0 to 14578
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14579 non-null  object
#  1   rougher.input.feed_au                               14579 non-null  float64
#  2   rougher.input.feed_ag                               14579 non-null  float64
#  3   rougher.input.feed_pb                               14507 non-null  float64
#  4   rougher.input.feed_sol                              14502 non-null  float64
#  5   rougher.input.feed_rate                             14572 non-null  float64
#  6   rougher.input.feed_size                             14478 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   14548 non-null  float64
# ...

# %% [markdown]
# **Описание данных**
#
# **Технологический процесс**
#
# **Rougher feed** — исходное сырье
# **Rougher additions** (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# **Xanthate** — ксантогенат (промотер, или активатор флотации);
# **Sulphate** — сульфат (на данном производстве сульфид натрия);
# **Depressant** — депрессант (силикат натрия).
# **Rougher process** (англ. «грубый процесс») — флотация
# **Rougher tails** — отвальные хвосты
# **Float banks** — флотационная установка
# **Cleaner process** — очистка
# **Rougher Au** — черновой концентрат золота
# **Final Au** — финальный концентрат золота
#
# **Параметры этапов**
#
# **air amount** — объём воздуха
# **fluid levels** — уровень жидкости
# **feed size** — размер гранул сырья
# **feed rate** — скорость подачи
#
# **Наименование признаков**
#
# Наименование признаков должно быть такое: [этап].[тип_параметра].[название_параметра]. Пример: rougher.input.feed_ag
#
# **Возможные значения для блока [этап]:**
#
# **rougher** — флотация
# **primary_cleaner** — первичная очистка
# **secondary_cleaner** — вторичная очистка
# **final** — финальные характеристики
#
# **Возможные значения для блока [тип_параметра]:**
#
# **input** — параметры сырья
# **output** — параметры продукта
# **state** — параметры, характеризующие текущее состояние этапа
# **calculation** — расчётные характеристики
#
# В нашем распоряжении три выборки: train, test, full. Дубликаты в данных отсутствуют, во всех таблицах есть пропуски. В тестовой выборке отсутствуют целевые признаки.

# %% [markdown]
# ### Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.

# %% [markdown]
# ![Recovery_1576238822.jpg](attachment:Recovery_1576238822.jpg)
#
# Эффективность обогащения рассчитывается по формуле выше.
#
# где:
# C — доля золота в концентрате после флотации/очистки;
# F — доля золота в сырье/концентрате до флотации/очистки;
# T — доля золота в отвальных хвостах после флотации/очистки.
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %%
# Вычисление recovery согласно формуле
C = train_data['rougher.output.concentrate_au']
F = train_data['rougher.input.feed_au']
T = train_data['rougher.output.tail_au']
recovery_calculated = (C * (F - T)) / (F * (C - T)) * 100

# Реальные значения recovery
recovery_actual = train_data['rougher.output.recovery']

# Сравнение средних значений
mean_recovery_actual = recovery_actual.mean()
mean_recovery_calculated = recovery_calculated.mean()

# Вывод средних значений
print(f'Среднее значение recovery_actual: {mean_recovery_actual:.4f}')
print(f'Среднее значение recovery_calculated: {mean_recovery_calculated:.4f}')
# Out:
# Среднее значение recovery_actual: 82.5212
# Среднее значение recovery_calculated: 82.5212

# %%
# Найдём MAE между моими расчётами и значением признака rougher.output.recovery:
# Вычисление MAE
mae = mean_absolute_error(train_data['rougher.output.recovery'], recovery_calculated)

# Вывод MAE
print(f'MAE между расчетами и фактическими значениями recovery: {mae:}')
# Out:
# MAE между расчетами и фактическими значениями recovery: 9.83758577644259e-15

# %% [markdown]
# Значения идентичны, значит эффективность обогощения была рассчитана корректно.

# %% [markdown]
# ### Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?

# %%
# Найти признаки, которые есть в train_data, но отсутствуют в test_data
missing_features = set(train_data.columns) - set(test_data.columns)

# Вывести список отсутствующих признаков
print("Признаки, которые есть в train_data, но отсутствуют в test_data:")
display(missing_features)
# Out:
# Признаки, которые есть в train_data, но отсутствуют в test_data:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
# ...

# %% [markdown]
# Признаки, которые присутствуют в обучающей выборке `train_data`, но отсутствуют в тестовой выборке `test_data`, в основном относятся к параметрам продукта и расчетным характеристикам на разных этапах технологического процесса обогащения золотосодержащей руды. Вот их краткое описание:
#
# Параметры продукта (`final.output`):
# - `final.output.concentrate_ag`: Концентрация серебра в конечном продукте.
# - `final.output.concentrate_au`: Концентрация золота в конечном продукте.
# - `final.output.concentrate_pb`: Концентрация свинца в конечном продукте.
# - `final.output.concentrate_sol`: Концентрация солей в конечном продукте.
# - `final.output.recovery`: Целевой признак - коэффициент восстановления золота на финальном этапе обогащения.
# - `final.output.tail_ag`: Концентрация серебра в отвальных хвостах после финального этапа обогащения.
# - `final.output.tail_au`: Концентрация золота в отвальных хвостах после финального этапа обогащения.
# - `final.output.tail_pb`: Концентрация свинца в отвальных хвостах после финального этапа обогащения.
# - `final.output.tail_sol`: Концентрация солей в отвальных хвостах после финального этапа обогащения.
#
# Параметры продукта и расчетные характеристики (`primary_cleaner.output`, `rougher.calculation`, `rougher.output`, `secondary_cleaner.output`):
# - `primary_cleaner.output.concentrate_ag`, `primary_cleaner.output.concentrate_au`, `primary_cleaner.output.concentrate_pb`, `primary_cleaner.output.concentrate_sol`: Концентрация веществ в продукте после первичной очистки.
# - `primary_cleaner.output.tail_ag`, `primary_cleaner.output.tail_au`, `primary_cleaner.output.tail_pb`, `primary_cleaner.output.tail_sol`: Концентрация веществ в отвальных хвостах после первичной очистки.
# - `rougher.calculation.au_pb_ratio`, `rougher.calculation.floatbank10_sulfate_to_au_feed`, `rougher.calculation.floatbank11_sulfate_to_au_feed`, `rougher.calculation.sulfate_to_au_concentrate`: Расчетные характеристики, связанные с определением оптимальных параметров и коэффициентов в различных этапах обработки.
# - `rougher.output.concentrate_ag`, `rougher.output.concentrate_au`, `rougher.output.concentrate_pb`, `rougher.output.concentrate_sol`: Концентрация веществ в продукте после флотации (грубого этапа обогащения).
# - `rougher.output.recovery`: Целевой признак - коэффициент восстановления золота на этапе флотации (грубого этапа обогащения).
# - `rougher.output.tail_ag`, `rougher.output.tail_au`, `rougher.output.tail_pb`, `rougher.output.tail_sol`: Концентрация веществ в отвальных хвостах после флотации (грубого этапа обогащения).
# - `secondary_cleaner.output.tail_ag`, `secondary_cleaner.output.tail_au`, `secondary_cleaner.output.tail_pb`, `secondary_cleaner.output.tail_sol`: Концентрация веществ в отвальных хвостах после вторичной очистки.
#
# Эти параметры представляют собой характеристики продукта и производственные параметры на различных этапах процесса обогащения золотосодержащей руды. Многие из них являются важными для оценки эффективности и оптимизации процесса.

# %% [markdown]
# Вывод:
#
# В реальных условиях технологического процесса данные могут поступать постоянно и обновляться в реальном времени. Онлайн-метрики могут использовать актуальные данные, в то время как для обучения модели могут использоваться исторические данные, которые включают в себя признаки, недоступные в test в силу актуальности информации.

# %% [markdown]
# ### Проведите предобработку данных.

# %%
# Ищем пропуски во всех датасетах
for dataset in data_all:
    missing_values = dataset.isna().sum()
    print("Пропущенные значения в датасете:")
    print(missing_values)
# Out:
# Пропущенные значения в датасете:
# date                       0
# rougher.input.feed_au      0
# rougher.input.feed_ag      0
# rougher.input.feed_pb     72
# rougher.input.feed_sol    77
#                           ..
# final.output.recovery      0
# final.output.tail_au       0
# final.output.tail_ag       1
# final.output.tail_pb      75
# final.output.tail_sol      5
# Length: 87, dtype: int64
# Пропущенные значения в датасете:
# date                                            0
# rougher.input.feed_au                           0
# rougher.input.feed_ag                           0
# rougher.input.feed_pb                          28
# rougher.input.feed_sol                         22
# rougher.input.feed_rate                         4
# rougher.input.feed_size                        44
# rougher.input.floatbank10_sulfate               3
# rougher.input.floatbank10_xanthate              1
# rougher.state.floatbank10_a_air                 1
# ...

# %% [markdown]
# Метод bfill.
#
# Для каждой ячейки с пропущенным значением будет использовано значение из следующей (нижней) строки в том же столбце. Это позволяет заполнять пропущенные значения на основе ближайших доступных данных, что может быть полезным в случае временных рядов или данных, где близкие во времени значения имеют схожие характеристики.
#
# Применение этого метода к тренировочным, тестовым и полным данным позволяет убедиться, что в каждом из них пропуски заполнены соответствующим образом, что важно для последующего анализа и построения моделей.

# %%
# Заполнение пропусков методом "заполнения назад" для всех столбцов
for dataset in data_all:
    dataset.fillna(method='bfill', axis=0, inplace=True)

# %% [markdown]
# От пропусков избавились, дубликатов в данных нет, проверку делали на этапе 1.1

# %%
# Проверка

for dataset in data_all:
  display(dataset.isna().sum())
# Out:
# date                      0
# rougher.input.feed_au     0
# rougher.input.feed_ag     0
# rougher.input.feed_pb     0
# rougher.input.feed_sol    0
#                          ..
# final.output.recovery     0
# final.output.tail_au      0
# final.output.tail_ag      0
# final.output.tail_pb      0
# final.output.tail_sol     0
# Length: 87, dtype: int64
# date                                          0
# rougher.input.feed_au                         0
# rougher.input.feed_ag                         0
# rougher.input.feed_pb                         0
# rougher.input.feed_sol                        0
# rougher.input.feed_rate                       0
# rougher.input.feed_size                       0
# rougher.input.floatbank10_sulfate             0
# rougher.input.floatbank10_xanthate            0
# rougher.state.floatbank10_a_air               0
# rougher.state.floatbank10_a_level             0
# rougher.state.floatbank10_b_air               0
# ...

# %% [markdown]
# Добавим в выборку test_data целевые признаки из full_data.

# %%
test_data = test_data.merge(full_data[['final.output.recovery', 'rougher.output.recovery', 'date']], on='date', how='left')
test_data.shape
# Out:
# (4860, 55)

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате. Какие особенности имеют распределения? Опишите выводы.

# %% [markdown]
# Данный анализ фокусируется на изменении концентрации трех металлов (золото - Au, серебро - Ag, свинец - Pb) на разных этапах процесса обработки руды: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.
#
# Для этого были извлечены соответствующие признаки концентрации для каждого металла на различных этапах обработки из датасета full_data.

# %%
# Выбираем столбцы с концентрацией каждого металла на разных этапах
concentration_au = full_data[['rougher.input.feed_au',
                              'rougher.output.concentrate_au',
                              'primary_cleaner.output.concentrate_au',
                              'final.output.concentrate_au']]

concentration_ag = full_data[['rougher.input.feed_ag',
                              'rougher.output.concentrate_ag',
                              'primary_cleaner.output.concentrate_ag',
                              'final.output.concentrate_ag']]

concentration_pb = full_data[['rougher.input.feed_pb',
                              'rougher.output.concentrate_pb',
                              'primary_cleaner.output.concentrate_pb',
                              'final.output.concentrate_pb']]

# Создаем функцию для построения гистограмм с разными цветами для каждого этапа
def plot_concentration_distribution(data, element):
    plt.figure(figsize=(12, 6))
    plt.title(f'Распределение концентрации {element} на разных этапах обработки')
    colors = ['blue', 'orange', 'green', 'red']
    
    for i, column in enumerate(data.columns):
        stage = ''
        if i == 0:
            stage = 'Сырье'
        elif i == 1:
            stage = 'Черновой концентрат'
        elif i == 2:
            stage = 'Концентрат после первой очистки'
        elif i == 3:
            stage = 'Финальный концентрат'
        sns.histplot(data[column], label=stage, bins=100, kde=True, color=colors[i])
    
    plt.xlabel(f'Концентрация {element}')
    plt.ylabel('Частота')
    plt.legend(title='Этапы обработки', loc='upper left')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# Строим гистограммы для каждого металла с разными цветами
plot_concentration_distribution(concentration_au, 'золота (Au)')
plot_concentration_distribution(concentration_ag, 'серебра (Ag)')
plot_concentration_distribution(concentration_pb, 'свинца (Pb)')

# %% [markdown]
# Посмотрим на линейном графике

# %%
# Данные для серебра
ag = full_data[['rougher.input.feed_ag', 'rougher.output.concentrate_ag',
                'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag']].mean(axis=0)
ag

# Данные для свинца
pb = full_data[['rougher.input.feed_pb', 'rougher.output.concentrate_pb',
                'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb']].mean(axis=0)
pb

# Данные для золота
au = full_data[['rougher.input.feed_au', 'rougher.output.concentrate_au',
                'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au']].mean(axis=0)
au
# Out:
# rougher.input.feed_au                     8.266097
# rougher.output.concentrate_au            19.772000
# primary_cleaner.output.concentrate_au    32.119400
# final.output.concentrate_au              44.076513
# dtype: float64

# %%
# Этапы обработки
stages = ['Сырье', 'Черновой концентрат', 'Концентрат после первой очистки', 'Финальный концентрат']

# Создаем график
plt.figure(figsize=(10, 6))

plt.plot(stages, ag, marker='o', label='Серебро')
plt.plot(stages, pb, marker='o', label='Свинец')
plt.plot(stages, au, marker='o', label='Золото')

plt.title('Изменение концентрации металлов на различных этапах обработки')
plt.xlabel('Этапы обработки')
plt.ylabel('Средняя концентрация')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# Из анализа изменения концентрации металлов на различных этапах обработки можно сделать следующие выводы:
#
# 1. **Серебро (Ag):**
#    - Концентрация серебра (Ag) существенно снижается после этапа флотации (первичной обработки). Это может свидетельствовать о том, что значительное количество серебра остается в отвальных хвостах после флотации. Этот результат может подсказывать о необходимости пересмотреть технологию очистки для Ag и снижения потерь серебра.
#
# 2. **Свинец (Pb):**
#    - Концентрация свинца (Pb) увеличивается постепенно от этапа к этапу, однако это происходит низкими темпами. Это может указывать на то, что процесс обогащения свинца требует дополнительных улучшений для повышения концентрации в конечном продукте.
#
# 3. **Золото (Au):**
#    - Концентрация золота (Au) также увеличивается с этапа на этап, но это происходит более быстро, особенно после этапа флотации. Это хорошая новость, так как концентрация золота в конечном продукте (финальном концентрате) растет более быстрыми темпами. Это позитивно с точки зрения производительности, поскольку конечный продукт, содержащий золото, является целевым результатом процесса обогащения.

# %% [markdown]
# Обнаружено, что большинство аномалий находятся на этапе черновой очистки, где наблюдается значительное количество нулевых или близких к нулю значений. В то время как на этапе подачи сырья аномалии практически отсутствуют, и на финальном этапе концентрации аномалий меньше, чем на этапе черновой очистки. Исходя из этого, было решено удалить эти аномальные значения. Это важный шаг, поскольку такие аномалии могут оказать влияние на конечные расчетные характеристики, и их удаление способствует более точным результатам анализа.

# %%
# Создаем список столбцов для проверки
columns_to_check = [
    'rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol', 'rougher.input.feed_au',
    'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol', 'rougher.output.concentrate_au',
    'primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_sol', 'primary_cleaner.output.concentrate_au',
    'final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol', 'final.output.concentrate_au'
]

# Проходим по каждому датафрейму и фильтруем строки, удаляя значения <= 1
for df in [full_data, train_data, test_data]:
    # Проверяем наличие столбцов в датафрейме перед фильтрацией
    existing_columns = [col for col in columns_to_check if col in df.columns]
    
    if existing_columns:
        df.drop(df[(df[existing_columns] <= 1).any(axis=1)].index, inplace=True)

# В результате, в каждом из датафреймов будут удалены строки, где хотя бы в одном из указанных столбцов значение <= 1.

# %% [markdown]
# ### Сравните распределения размеров гранул исходного сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %%
# Установим размер графика
plt.figure(figsize=(10, 6))

# Построим нормированные гистограммы для размеров гранул исходного сырья
sns.histplot(train_data['rougher.input.feed_size'], bins=50, kde=True, color='blue', label='Обучающая выборка', stat='density')
sns.histplot(test_data['rougher.input.feed_size'], bins=50, kde=True, color='orange', label='Тестовая выборка', stat='density')

# Обрежем график по оси x до 200
plt.xlim(0, 200)

# Добавим легенду и подписи к осям
plt.xlabel('Размер гранул исходного сырья')
plt.ylabel('Плотность вероятности')
plt.title('Распределение размеров гранул исходного сырья на обучающей и тестовой выборках')
plt.legend()

# %% [markdown]
# Сформулирует гипотезы:
#
# Нулевая гипотеза (H0): Средние значения размеров гранул исходного сырья в обучающей и тестовой выборках равны.
# Альтернативная гипотеза (H1): Средние значения размеров гранул исходного сырья в обучающей и тестовой выборках различаются.

# %%
# Проведем t-тест для оценки схожести распределений
alpha = 0.05  # Уровень значимости

# %%
t_stat, p_value = stats.ttest_ind(train_data['rougher.input.feed_size'], test_data['rougher.input.feed_size'], equal_var=False)

# %%
print(f"t-статистика: {t_stat}")
print(f"p-value: {p_value}")

if p_value < alpha:
    print("Отвергаем нулевую гипотезу: Средние значения размеров гранул различаются.")
else:
    print("Не отвергаем нулевую гипотезу: Средние значения размеров гранул схожи.")

# Выведем график
plt.show()
# Out:
# t-статистика: -1.118345841273274
# p-value: 0.2634473149499856
# Не отвергаем нулевую гипотезу: Средние значения размеров гранул схожи.

# %% [markdown]
# В результате анализа распределений размеров гранул исходного сырья на обучающей и тестовой выборках было проведено сравнение с использованием нормированных гистограмм и статистического теста t-тест. Полученные результаты говорят о том, что средние значения размеров гранул схожи между обучающей и тестовой выборками. Следовательно, отсутствуют значительные отличия в распределениях размеров гранул исходного сырья между этими двумя выборками.
#
# Это важное наблюдение, так как различия в распределениях могли бы повлиять на корректность оценки модели. Теперь можно продолжать анализ и обучение модели с уверенностью в схожести данных в этом аспекте.

# %% [markdown]
# ### Исследуйте суммарную концентрацию металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.

# %%
# Для сырья
sum_feed = full_data[['rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol', 'rougher.input.feed_au']].sum(axis=1)

# Для чернового концентрата
sum_rougher_output = full_data[['rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol', 'rougher.output.concentrate_au']].sum(axis=1)

# Для концентрата после первой очистки
sum_primary_cleaner_output = full_data[['primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_sol', 'primary_cleaner.output.concentrate_au']].sum(axis=1)

# Для финального концентрата
sum_final_output = full_data[['final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol', 'final.output.concentrate_au']].sum(axis=1)

# Функция для построения гистограмм
def plot_histogram(data, stage):
    plt.figure(figsize=(10, 6))
    sns.histplot(data, bins=30, kde=True, color='blue')
    plt.title(f'Суммарная концентрация металлов на этапе {stage}')
    plt.xlabel('Суммарная концентрация')
    plt.ylabel('Частота')
    plt.show()

# Гистограммы для каждого этапа
plot_histogram(sum_feed, 'сырье')
plot_histogram(sum_rougher_output, 'черновой концентрат')
plot_histogram(sum_primary_cleaner_output, 'концентрат после первой очистки')
plot_histogram(sum_final_output, 'финальный концентрат')

# %%
# Установим размер графика
plt.figure(figsize=(10, 6))

# Построим гистограмму суммарной концентрации металлов для сырья
sns.histplot(sum_feed, bins=30, kde=True, color='blue', label='Сырье')

# Построим гистограмму суммарной концентрации металлов для чернового концентрата
sns.histplot(sum_rougher_output, bins=30, kde=True, color='orange', label='Черновой концентрат')

# Построим гистограмму суммарной концентрации металлов для концентрата после первой очистки
sns.histplot(sum_primary_cleaner_output, bins=30, kde=True, color='green', label='Концентрат после первой очистки')

# Построим гистограмму суммарной концентрации металлов для финального концентрата
sns.histplot(sum_final_output, bins=30, kde=True, color='red', label='Финальный концентрат')

# Добавим легенду и подписи к осям
plt.xlabel('Суммарная концентрация металлов')
plt.ylabel('Частота')
plt.title('Динамика суммарной концентрации металлов на разных этапах обработки')
plt.legend()

# Отобразим график
plt.show()

# %% [markdown]
# **Вывод:**
#
# Исходя из проведенного анализа суммарной концентрации металлов на разных стадиях технологического процесса, можно сделать следующие выводы:
#
# 1. На этапе сырья (входное сырье) средняя суммарная концентрация металлов составляет около 58, а максимальная частота концентрации в районе 3000. Это означает, что входное сырье содержит металлы, но их концентрация не очень высока.
#
# 2. На этапе чернового концентрата средняя суммарная концентрация металлов увеличивается и составляет около 70, а максимальная частота концентрации достигает 3500. Это свидетельствует о том, что после первичной обработки концентрация металлов увеличивается.
#
# 3. После первой очистки средняя суммарная концентрация металлов составляет около 65, а максимальная частота концентрации достигает 4000. Это подтверждает эффективность первичной очистки.
#
# 4. На этапе финального концентрата средняя суммарная концентрация металлов вновь увеличивается и составляет около 70, а максимальная частота концентрации достигает 7000. Это говорит о том, что после финальной обработки концентрация металлов увеличивается до максимальных значений.
#
# Таким образом, процесс обработки сырья позволяет увеличить концентрацию металлов, достигая максимальных значений на этапе финального концентрата.

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Напишите функцию для вычисления итоговой sMAPE.

# %% [markdown]
# Функция Symmetric Mean Absolute Percentage Error (sMAPE) является метрикой для оценки точности моделей прогнозирования, особенно в случаях, когда значения предсказанных и фактических величин могут быть равны нулю или очень близки к нему.
#
# sMAPE вычисляется как среднее абсолютных процентных ошибок для каждой пары предсказанных и фактических значений. Она измеряет процентное отклонение предсказанных значений от фактических, учитывая их абсолютные значения.ъ
#
# ![smape_1576239058.jpg](attachment:smape_1576239058.jpg)

# %%
# Создадим функцию
def sMAPE(y_target, y_predict):
    smape = np.mean(abs(y_target - y_predict) / ((abs(y_target) + abs(y_predict)) / 2)) * 100
    return smape

# %% [markdown]
# ![_smape_1576239054.jpg](attachment:_smape_1576239054.jpg)

# %%
# Вычисление финального sMAPE
def final_sMAPE(smape_rougher, smape_final):
    return (0.25*smape_rougher + 0.75*smape_final)

# %% [markdown]
# ### Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.

# %%
# Удаляем столбец 'date' из данных
train_data = train_data.drop('date', axis=1)
test_data = test_data.drop('date', axis=1)

# %%
# Создаем список столбцов, которые необходимо исключить на основе определенных критериев
features_to_exclude = []

# Исключаем столбцы, содержащие в названии фразу "output.recovery"
features_to_exclude.extend([col for col in train_data.columns if 'output.recovery' in col])

# Исключаем столбцы, содержащие в названии фразы "output.concentrate" или "output.tail"
features_to_exclude.extend([col for col in train_data.columns if 'output.concentrate' in col or 'output.tail' in col])

# Исключаем столбцы, содержащие в названии фразы "calculation" или "ratio"
features_to_exclude.extend([col for col in train_data.columns if 'calculation' in col or 'ratio' in col])

# %%
# Выделяем признаки и целевые переменные для грубой очистки и финального продукта
features_train_rougher = train_data.drop(features_to_exclude, axis=1).values
target_train_rougher = train_data['rougher.output.recovery'].values

features_train_final = train_data.drop(features_to_exclude, axis=1).values
target_train_final = train_data['final.output.recovery'].values

# Получение признаков и целевых переменных для тестовой выборки грубой очистки и финального продукта (для проверки на финальном этапе)
features_test = np.array(test_data.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1))
target_test_rougher = np.array(test_data['rougher.output.recovery'])
target_test_final = np.array(test_data['final.output.recovery'])

# Выводим размерности массивов для грубой очистки
print("Грубая очистка:")
print("Признаки:", features_train_rougher.shape)
print("Целевая переменная (грубая очистка):", target_train_rougher.shape)

# Выводим размерности массивов для финального продукта
print("Финальный продукт:")
print("Признаки:", features_train_final.shape)
print("Целевая переменная (финальный продукт):", target_train_final.shape)
# Out:
# Грубая очистка:
# Признаки: (13659, 52)
# Целевая переменная (грубая очистка): (13659,)
# Финальный продукт:
# Признаки: (13659, 52)
# Целевая переменная (финальный продукт): (13659,)

# %% [markdown]
# Это функция из библиотеки scikit-learn (sklearn), которая позволяет создавать пользовательские оценщики (scorers). Оценщики используются для измерения производительности моделей, и они могут быть стандартными метриками, такими как среднеквадратичная ошибка (MSE), средняя абсолютная ошибка (MAE), или пользовательские метрики, такие как sMAPE (симметричное среднее абсолютное процентное отклонение).
#
# greater_is_better = False: Этот аргумент указывает, что меньшие значения sMAPE лучше.

# %%
score = make_scorer(sMAPE, greater_is_better = False)

# %%
# Создаем модели с использованием StandardScaler
lasso_model = make_pipeline(StandardScaler(), Lasso(random_state=12345))
rf_model = make_pipeline(StandardScaler(), RandomForestRegressor(random_state=12345))
dtr_model = make_pipeline(StandardScaler(), DecisionTreeRegressor(random_state=12345))

# %%
# Задаем параметры для моделей
lasso_params = {'lasso__alpha': [0.001, 0.01, 0.1, 1.0]}
rf_params = {
    'randomforestregressor__n_estimators': [10,50],  
    'randomforestregressor__max_depth': [None, 5, 10]
}
dtr_params = {
    'decisiontreeregressor__max_depth': [None, 10, 20],
    'decisiontreeregressor__min_samples_split': [2, 5, 10],
    'decisiontreeregressor__min_samples_leaf': [1, 2, 4]
}

# %%
# Создаем объекты GridSearchCV для Lasso, RandomForestRegressor и LinearRegression для грубой очистки (rougher)
grid_rougher_lasso = GridSearchCV(lasso_model, lasso_params, cv=5, scoring=score)
grid_rougher_rf = GridSearchCV(rf_model, rf_params, cv=5, scoring=score)
grid_rougher_dtr = GridSearchCV(dtr_model, dtr_params, cv=5, scoring=score)

# Создаем объекты GridSearchCV для Lasso, RandomForestRegressor и LinearRegression для финального продукта (final)
grid_final_lasso = GridSearchCV(lasso_model, lasso_params, cv=5, scoring=score)
grid_final_rf = GridSearchCV(rf_model, rf_params, cv=5, scoring=score)
grid_final_dtr = GridSearchCV(dtr_model, dtr_params, cv=5, scoring=score)

# %% [markdown]
# **LASSO**

# %%
# Обучаем модели для грубой очистки (rougher)
with tqdm(total=1, desc="Обучение моделей для грубой очистки, модель LASSO") as pbar:
    grid_rougher_lasso.fit(features_train_rougher, target_train_rougher)
    pbar.update(1)
# Out:
# Обучение моделей для грубой очистки, модель LASSO: 100%|██████████| 1/1 [33:40<00:00, 2020.90s/it]

# %% [markdown]
# **DecisionTreeRegressor**

# %%
with tqdm(total=1, desc="Обучение моделей для грубой очистки, модель DecisionTreeRegressor") as pbar:
    grid_rougher_dtr.fit(features_train_rougher, target_train_rougher)
    pbar.update(1)
# Out:
# Обучение моделей для грубой очистки, модель DecisionTreeRegressor: 100%|██████████| 1/1 [01:33<00:00, 93.63s/it]

# %% [markdown]
# **RandomForestRegressor**

# %%
with tqdm(total=1, desc="Обучение моделей для грубой очистки, модель RandomForestRegressor") as pbar:
    grid_rougher_rf.fit(features_train_rougher, target_train_rougher)
    pbar.update(1)
# Out:
# Обучение моделей для грубой очистки, модель RandomForestRegressor: 100%|██████████| 1/1 [04:53<00:00, 293.31s/it]

# %% [markdown]
# **LASSO final**

# %%
# Обучаем модели для финального продукта (final)
with tqdm(total=1, desc="Обучение моделей для финального продукта модель LASSO") as pbar:
    grid_final_lasso.fit(features_train_final, target_train_final)
    pbar.update(1)
# Out:
# Обучение моделей для финального продукта модель LASSO: 100%|██████████| 1/1 [46:03<00:00, 2763.19s/it]

# %% [markdown]
# **DecisionTreeRegressor final**

# %%
with tqdm(total=1, desc="Обучение моделей для финального продукта, модель DecisionTreeRegressor") as pbar:
    grid_final_dtr.fit(features_train_final, target_train_final)
    pbar.update(1)
# Out:
# Обучение моделей для финального продукта, модель DecisionTreeRegressor: 100%|██████████| 1/1 [01:45<00:00, 105.52s/it]

# %% [markdown]
# **RandomForestRegressor final**

# %%
with tqdm(total=1, desc="Обучение моделей для финального продукта, модель RandomForestRegressor") as pbar:
    grid_final_rf.fit(features_train_final, target_train_final)
    pbar.update(1)
# Out:
# Обучение моделей для финального продукта, модель RandomForestRegressor: 100%|██████████| 1/1 [05:44<00:00, 344.30s/it]

# %%
# Выводим результаты для грубой очистки
print("Лучшие гиперпараметры и оценки для грубой очистки (rougher):")
print("Lasso:", grid_rougher_lasso.best_params_, "SMAPE:", -grid_rougher_lasso.best_score_)
print("RandomForestRegressor:", grid_rougher_rf.best_params_, "SMAPE:", -grid_rougher_rf.best_score_)
print("DecisionTreeRegressor:", grid_rougher_dtr.best_params_, "SMAPE:", -grid_rougher_dtr.best_score_)
# Out:
# Лучшие гиперпараметры и оценки для грубой очистки (rougher):
# Lasso: {'lasso__alpha': 1.0} SMAPE: 6.215731746077584
# RandomForestRegressor: {'randomforestregressor__max_depth': 5, 'randomforestregressor__n_estimators': 50} SMAPE: 6.367623618099378
# DecisionTreeRegressor: {'decisiontreeregressor__max_depth': 10, 'decisiontreeregressor__min_samples_leaf': 4, 'decisiontreeregressor__min_samples_split': 10} SMAPE: 8.064778315083208

# %%
# Выводим результаты для финального продукта
print("Лучшие гиперпараметры и оценки для финального продукта (final):")
print("Lasso:", grid_final_lasso.best_params_, "SMAPE:", -grid_final_lasso.best_score_)
print("RandomForestRegressor:", grid_final_rf.best_params_, "SMAPE:", -grid_final_rf.best_score_)
print("DecisionTreeRegressor:", grid_final_dtr.best_params_, "SMAPE:", -grid_final_dtr.best_score_)
# Out:
# Лучшие гиперпараметры и оценки для финального продукта (final):
# Lasso: {'lasso__alpha': 1.0} SMAPE: 8.564919508513109
# RandomForestRegressor: {'randomforestregressor__max_depth': 5, 'randomforestregressor__n_estimators': 50} SMAPE: 8.980535796340979
# DecisionTreeRegressor: {'decisiontreeregressor__max_depth': 10, 'decisiontreeregressor__min_samples_leaf': 4, 'decisiontreeregressor__min_samples_split': 2} SMAPE: 11.402267566236489

# %% [markdown]
# Согласно метрике sMAPE, лучшей моделью для грубой очистки (rougher) является Lasso с sMAPE равным 6.22. Для финального продукта (final) также лучшей моделью оказывается Lasso с sMAPE равным 8.56.
#
# Таким образом, Lasso - это лучшая модель как для грубой очистки, так и для финального продукта на основе данной метрики.

# %%
final_smape_lasso = final_sMAPE(-grid_rougher_lasso.best_score_, -grid_final_lasso.best_score_)
print('по модели LASSO итоговое sMAPE =', final_smape_lasso)

final_smape_dtr = final_sMAPE(-grid_rougher_dtr.best_score_, -grid_final_dtr.best_score_)
print('по модели DecisionTreeRegressor итоговое sMAPE =', final_smape_dtr)

final_smape_rf = final_sMAPE(-grid_rougher_rf.best_score_, -grid_final_rf.best_score_)
print('по модели RandomForestRegressor итоговое sMAPE =', final_smape_rf)
# Out:
# по модели LASSO итоговое sMAPE = 7.977622567904228
# по модели DecisionTreeRegressor итоговое sMAPE = 10.56789525344817
# по модели RandomForestRegressor итоговое sMAPE = 8.327307751780578

# %% [markdown]
# ### Проверим модель на тестовой выборке

# %%
# Получение предсказаний модели Lasso для тестовой выборки грубой очистки
predictions_rougher = grid_rougher_lasso.predict(features_test)

# Получение предсказаний модели Lasso для тестовой выборки финального продукта
predictions_final = grid_final_lasso.predict(features_test)

# Вычисление sMAPE для тестовой выборки грубой очистки
smape_rougher = sMAPE(target_test_rougher, predictions_rougher)

# Вычисление sMAPE для тестовой выборки финального продукта
smape_final = sMAPE(target_test_final, predictions_final)

# Вычисление итогового sMAPE на основе sMAPE для грубой очистки и финального продукта
final_smape = final_sMAPE(smape_rougher, smape_final)

# Вывод итогового значения sMAPE
print('sMAPE модели LASSO на тестовой выборке =', final_smape)
# Out:
# sMAPE модели LASSO на тестовой выборке = 7.340431749562608

# %% [markdown]
# ### Проверим модель на адекватность.

# %%
# Создаем константную модель, предсказывающую среднее значение тренировочной выборки для грубой очистки
dummy_rougher = DummyRegressor(strategy='mean')
dummy_rougher.fit(features_train_rougher, target_train_rougher)

# Создаем константную модель, предсказывающую среднее значение тренировочной выборки для финального продукта
dummy_final = DummyRegressor(strategy='mean')
dummy_final.fit(features_train_final, target_train_final)

# Предсказываем с константными моделями
dummy_predictions_rougher = dummy_rougher.predict(features_test)
dummy_predictions_final = dummy_final.predict(features_test)

# Вычисляем sMAPE для константных моделей
dummy_smape_rougher = sMAPE(target_test_rougher, dummy_predictions_rougher)
dummy_smape_final = sMAPE(target_test_final, dummy_predictions_final)

# Вычисляем final_sMAPE для константной модели
dummy_final_smape_test = final_sMAPE(dummy_smape_rougher, dummy_smape_final)

print('sMAPE для константной модели:', dummy_final_smape_test)
# Out:
# sMAPE для константной модели: 8.392266066213942

# %% [markdown]
# ## Общий вывод.

# %% [markdown]
# В рамках данного проекта было выполнено исследование и разработка модели для оптимизации процессов обработки руды на предприятии. Главной задачей было предсказание коэффициента восстановления золота из золотосодержащей руды на двух этапах: грубой и финальной очистки. Для этого были проанализированы и предобработаны данные, построены и обучены модели машинного обучения, и затем проведена оценка качества моделей на тестовой выборке.
#
# Исходя из метрики симметричной средней абсолютной процентной ошибки (sMAPE), лучшей моделью для предсказания коэффициента восстановления золота оказалась модель LASSO с полученным sMAPE равным 7.34 на тестовой выборке. Это позволяет сделать вывод о том, что данная модель обладает наилучшей точностью в предсказании процесса обогащения золотосодержащей руды.
